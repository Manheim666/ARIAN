# %% [markdown]
# # 01 — Data Ingestion
#
# **Phase 1 of the Weather → Climate → Wildfire pipeline.**
#
# This notebook is the **single entry point** for loading every raw source the
# project depends on, validating it, and writing a clean, analysis-ready copy
# to `data/interim/`. All heavy lifting lives in `src/weather/ingestion.py`;
# this notebook orchestrates, inspects and reports.
#
# ---
#
# ## Data sources
#
# | # | Source | File(s) | Purpose |
# |---|---|---|---|
# | 1 | **Open-Meteo archive** | `data/raw/openmeteo/hourly_weather.csv`, `daily_weather.csv` | Weather history (core) |
# | 2 | **WorldPop population** | `data/raw/population/population_YYYY.csv` | Human-activity proxy |
# | 3 | **OSM road network** | `data/raw/osm_roads/static_city_infrastructure.csv` | Human-access proxy |
# | 4 | **MODIS NDVI (GEE)** | `data/raw/earth_engine/aze_ndvi_2020_2026.csv` | Vegetation dryness |
# | 5 | **NASA FIRMS VIIRS** | `data/raw/nasa_firms/viirs-snpp_*.csv` | Historical wildfire labels |
# | 6 | **Lightning climatology** | `data/raw/lightning/azerbaijan_lightning_*.csv` | Natural ignition source |
# | 7 | **Forest boundaries** | `data/raw/forest_boundaries/azerbaijan.kmz` | Fuel map |
# | 8 | **ESA WorldCover** | `data/raw/earth_engine/aze_landcover.tif` | Landcover per city |
#
# ## Outputs
#
# Every loader writes to `data/interim/`:
#
# ```
# weather_hourly_raw.csv      # Core weather — 5 cities × hourly grid
# weather_daily_raw.csv       # Daily rain sum
# cities_reference.csv        # Name, lat, lon for 16 study cities
# population.csv              # Stacked 2020–2026
# roads.csv                   # Human-access road density
# ndvi.csv                    # Daily NDVI per city
# firms.csv                   # Fire hotspots + combined timestamp
# lightning.csv               # Grid-month thunder-hours
# forest_boundaries.geojson   # (optional) geopandas / fiona required
# landcover_at_cities.csv     # (optional) rasterio required
# ```

# %% [markdown]
# ## 1. Setup
#
# Make `src/` importable from the notebook and pull in the ingestion helpers.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

# Make the project root importable no matter where Jupyter was launched from
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").is_dir() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

import pandas as pd
pd.set_option("display.max_columns", 40)
pd.set_option("display.width", 160)

from src.weather import ingestion
from src.utils.config import (
    AZERBAIJAN_CITIES, INTERIM_DIR, RAW_OPENMETEO,
    HOURLY_WEATHER_VARS, FORECAST_TARGETS,
)
from src.utils.logging_utils import get_logger
logger = get_logger("nb.01_ingestion")
logger.info("Setup complete - %d cities in scope", len(AZERBAIJAN_CITIES))
# Out:
# Project root: c:\Users\pc\Downloads\ARIAN - Copy
# 18:46:59 | INFO    | nb.01_ingestion | Setup complete - 16 cities in scope

# %% [markdown]
# ## 2. Weather — Open-Meteo historical archive
#
# The Open-Meteo REST API serves hourly history from 2020-01-01 to the present
# for every lat/lon, free of charge. We cached a 2020–2026 snapshot under
# `data/raw/openmeteo/` so the notebook runs offline; the same function can
# refresh directly from the API when network access is available.
#
# ### 2a. Load from disk (default path)

# %%
weather_hourly, weather_daily = ingestion.load_weather_from_disk()
weather_hourly.head(3)
# Out:
# 18:47:09 | INFO    | src.weather.ingestion | Reading hourly weather  <- C:\Users\pc\Downloads\ARIAN - Copy\data\raw\openmeteo\hourly_weather.csv
# 18:47:12 | INFO    | src.weather.ingestion | Reading daily weather   <- C:\Users\pc\Downloads\ARIAN - Copy\data\raw\openmeteo\daily_weather.csv
# 18:47:12 | INFO    | src.weather.ingestion | Hourly: 276,000 rows, 5 cities, 2020-01-01 00:00:00+00:00 -> 2026-04-18 23:00:00+00:00
# 18:47:12 | INFO    | src.weather.ingestion | Daily:  11,500 rows, 5 cities, 2020-01-01 00:00:00+00:00 -> 2026-04-18 00:00:00+00:00
#    City                      date  temperature_2m  relative_humidity_2m  dew_point_2m  precipitation  rain  cloud_cover  cloud_cover_low  cloud_cover_mid  \
# 0  Baku 2020-01-01 00:00:00+00:00             5.0                 100.0           5.0            0.0   0.0        100.0            100.0              0.0
# 1  Baku 2020-01-01 01:00:00+00:00             5.5                 100.0           5.5            0.0   0.0        100.0            100.0              0.0
# 2  Baku 2020-01-01 02:00:00+00:00             3.6                 100.0           3.6            0.0   0.0         80.0             80.0              0.0
#
#    cloud_cover_high  vapour_pressure_deficit  evapotranspiration  wind_speed_10m  wind_direction_10m  wind_speed_80m  wind_direction_80m  temperature_80m  \
# 0               0.0                      0.0                 NaN        5.154416           282.09473             NaN                 NaN              NaN
# 1               0.0                      0.0                 NaN        4.693826           212.47118             NaN                 NaN              NaN
# 2               0.0                      0.0                 NaN        9.007196           182.29056             NaN                 NaN              NaN
#
#    wind_gusts_10m  soil_temperature_0_to_7cm  soil_temperature_7_to_28cm  soil_temperature_28_to_100cm  is_day  sunshine_duration  shortwave_radiation  \
# 0       10.440001                       7.05                        9.60                          11.3     0.0                0.0                  0.0
# 1        6.840000                       6.50                        9.45                          11.3     0.0                0.0                  0.0
# 2       12.240000                       6.15                        9.25                          11.3     0.0                0.0                  0.0
#
#    direct_radiation
# 0               0.0
# 1               0.0
# 2               0.0

# %% [markdown]
# ### 2b. Validate structural integrity
#
# `validate_weather_df` reports row counts, city coverage, date range, missing-cell
# percentage, and — crucially — whether the hourly / daily cadence has any gaps.

# %%
hourly_report = ingestion.validate_weather_df(weather_hourly, kind="hourly")
daily_report  = ingestion.validate_weather_df(weather_daily,  kind="daily")

summary = pd.DataFrame({
    "hourly": {k: v for k, v in hourly_report.items() if k != "timestep_gaps_per_city"},
    "daily":  {k: v for k, v in daily_report.items()  if k != "timestep_gaps_per_city"},
})
summary
# Out:
#                                   hourly                      daily
# rows                              276000                      11500
# cities                                 5                          5
# date_min       2020-01-01 00:00:00+00:00  2020-01-01 00:00:00+00:00
# date_max       2026-04-18 23:00:00+00:00  2026-04-18 00:00:00+00:00
# missing_cells                    1104000                          0
# missing_pct                     0.166667                        0.0

# %%
# Gap analysis per city (0 = perfect cadence)
pd.DataFrame({
    "hourly_gaps": hourly_report["timestep_gaps_per_city"],
    "daily_gaps":  daily_report["timestep_gaps_per_city"],
}).fillna(0).astype(int)
# Out:
#           hourly_gaps  daily_gaps
# Baku                0           0
# Ganja               0           0
# Guba                0           0
# Lankaran            0           0
# Zaqatala            0           0

# %% [markdown]
# ### 2c. (Optional) Refresh directly from the Open-Meteo API
#
# Uncomment the cell below to re-download. Requires `openmeteo_requests`,
# `requests_cache` and `retry_requests`, plus network access.

# %%
# hourly_api, daily_api = ingestion.fetch_weather_from_api()
# hourly_api.head()

# %% [markdown]
# ## 3. Cities reference table
#
# A tiny but important artefact: the canonical mapping from city name to
# centroid coordinates, used by every downstream join.

# %%
from src.utils.config import cities_as_records
cities_df = pd.DataFrame(cities_as_records())
cities_df
# Out:
#            City  Latitude  Longitude
# 0          Baku   40.4093    49.8671
# 1         Ganja   40.6828    46.3606
# 2      Lankaran   38.7529    48.8515
# 3          Guba   41.3597    48.5134
# 4      Zaqatala   41.6336    46.6433
# 5    Nakhchivan   39.2089    45.4122
# 6         Sheki   41.1919    47.1706
# 7       Shirvan   39.9317    48.9290
# 8   Mingachevir   40.7639    47.0595
# 9      Khachmaz   41.4635    48.8060
# 10      Goychay   40.6533    47.7401
# 11      Shamkir   40.8298    46.0162
# 12    Sabirabad   40.0101    48.4772
# 13      Imishli   39.8694    48.0600
# 14     Shamakhi   40.6303    48.6414
# 15    Jalilabad   39.2096    48.4919

# %% [markdown]
# ## 4. Auxiliary sources
#
# Each loader is independent and validated in isolation — a failure in one
# source never takes down the others.

# %% [markdown]
# ### 4a. Population (WorldPop, rasterised to city centroids)

# %%
population = ingestion.load_population()
population.pivot_table(index="City", columns="Year", values="Pop_Density").round(1)
# Out:
# 14:15:22 | INFO    | src.weather.ingestion | Population: 112 rows across years 2020-2026, 16 cities
# Year         2020  2021  2022  2023  2024  2025  2026
# City
# Baku         69.3  69.7  70.1  70.7  70.5  71.0  71.4
# Ganja        74.6  75.0  75.3  75.9  75.7  76.1  76.5
# Goychay      25.6  25.7  25.8  26.0  25.9  26.1  26.2
# Guba         45.0  45.2  45.5  45.7  45.6  45.8  46.0
# Imishli      35.7  35.9  36.1  36.3  36.2  36.4  36.6
# Jalilabad    50.0  50.3  50.5  50.9  50.8  51.1  51.4
# Khachmaz     38.6  38.8  38.9  39.2  39.1  39.3  39.5
# Lankaran     51.2  51.4  51.6  51.9  51.8  52.0  52.2
# Mingachevir  53.0  53.3  53.6  53.9  53.8  54.1  54.4
# Nakhchivan   65.5  65.8  66.1  66.5  66.4  66.7  67.1
# Sabirabad    20.5  20.6  20.7  20.8  20.8  20.9  21.0
# Shamakhi     48.9  49.2  49.4  49.7  49.6  49.8  50.0
# Shamkir      24.9  25.0  25.1  25.2  25.2  25.3  25.4
# Sheki        35.2  35.4  35.6  35.8  35.7  35.9  36.1
# Shirvan      14.7  14.7  14.8  14.9  14.9  14.9  15.0
# Zaqatala     37.8  38.0  38.1  38.4  38.3  38.5  38.7

# %% [markdown]
# ### 4b. Roads (OSM human-access within 5 km of each city)

# %%
roads = ingestion.load_roads_static()
roads.sort_values("human_access_road_meters", ascending=False)
# Out:
# 14:15:23 | INFO    | src.weather.ingestion | Roads: 16 cities, total 11537 km
#            City  human_access_road_meters
# 1         Ganja              1.663040e+06
# 0          Baku              1.470499e+06
# 9      Khachmaz              7.732498e+05
# 6         Sheki              7.474569e+05
# 5    Nakhchivan              6.789007e+05
# 3          Guba              6.767788e+05
# 11      Shamkir              6.702843e+05
# 2      Lankaran              6.678211e+05
# 7       Shirvan              6.599856e+05
# 10      Goychay              6.122606e+05
# 4      Zaqatala              5.981776e+05
# 15    Jalilabad              5.030194e+05
# 14     Shamakhi              4.734204e+05
# 12    Sabirabad              4.663535e+05
# 8   Mingachevir              4.449396e+05
# 13      Imishli              4.309578e+05

# %% [markdown]
# ### 4c. NDVI (MODIS, per city, Earth Engine export)

# %%
ndvi = ingestion.load_ndvi()
print(ndvi.groupby("City")["NDVI"].agg(["min", "mean", "max"]).round(3))
ndvi.head(3)
# Out:
# 14:15:23 | INFO    | src.weather.ingestion | NDVI: 2304 rows, 16 cities, 2020-01-01 00:00:00+00:00 -> 2026-03-22 00:00:00+00:00
#                min   mean    max
# City
# Baku         0.011  0.200  0.306
# Ganja        0.009  0.199  0.339
# Goychay      0.056  0.344  0.470
# Guba         0.006  0.286  0.507
# Imishli      0.137  0.303  0.417
# Jalilabad   -0.010  0.359  0.489
# Khachmaz     0.042  0.294  0.464
# Lankaran    -0.005  0.325  0.584
# Mingachevir  0.011  0.325  0.505
# Nakhchivan   0.008  0.179  0.278
# Sabirabad    0.076  0.307  0.488
# Shamakhi     0.005  0.338  0.565
# Shamkir      0.006  0.288  0.446
# Sheki        0.005  0.301  0.484
# Shirvan      0.043  0.259  0.384
# Zaqatala     0.002  0.353  0.528
#    City                      date    NDVI
# 0  Baku 2020-01-01 00:00:00+00:00  0.1624
# 1  Baku 2020-01-17 00:00:00+00:00  0.1926
# 2  Baku 2020-02-02 00:00:00+00:00  0.1294

# %% [markdown]
# ### 4d. NASA FIRMS (VIIRS wildfire hotspots)

# %%
firms = ingestion.load_firms()
print("Annual fire counts:")
print(firms["acq_date"].dt.year.value_counts().sort_index())
firms[["latitude", "longitude", "acq_timestamp", "bright_ti4", "frp", "confidence", "daynight"]].head(3)
# Out:
# 14:15:23 | INFO    | src.weather.ingestion | FIRMS: 21218 hotspots, 2020-01-01 00:00:00 -> 2024-12-31 00:00:00
# Annual fire counts:
# acq_date
# 2020    5196
# 2021    5667
# 2022    4814
# 2023    2842
# 2024    2699
# Name: count, dtype: int64
#    latitude  longitude             acq_timestamp  bright_ti4   frp confidence daynight
# 0  40.19473   49.46200 2020-01-01 10:23:00+00:00      338.08  4.21          n        D
# 1  40.19724   49.46228 2020-01-01 10:23:00+00:00      344.28  3.65          n        D
# 2  41.16796   45.25504 2020-01-01 22:42:00+00:00      296.02  0.72          n        N

# %% [markdown]
# ### 4e. Lightning (climatology grid)

# %%
lightning = ingestion.load_lightning()
print("Thunder-hours per month (all years pooled):")
print(lightning.groupby("month")["thunder_hours"].sum())
lightning.head(3)
# Out:
# 14:15:23 | INFO    | src.weather.ingestion | Lightning: 366619 grid-month obs over 6 years
# Thunder-hours per month (all years pooled):
# month
# 1       3435
# 2       4309
# 3      35622
# 4     191125
# 5     463019
# 6     372981
# 7     199579
# 8     207453
# 9     190264
# 10    132314
# 11     14477
# 12      6388
# Name: thunder_hours, dtype: int64
#       lat     lon  month  thunder_hours  year
# 0  38.025  50.525      1              1  2020
# 1  38.025  50.575      1              2  2020
# 2  38.025  50.625      1              2  2020

# %% [markdown]
# ### 4f. Forest boundaries and landcover (require `geopandas` / `rasterio`)
#
# These cells skip themselves with a clear message if the optional geo libraries
# are missing — the pipeline still produces complete tabular outputs.

# %%
try:
    forests = ingestion.load_forest_boundaries()
    print(f"Forests: {len(forests)} polygons, CRS={forests.crs}")
    forests.head(3)
except RuntimeError as exc:
    print(f"[skipped] {exc}")
    forests = None
forests
# Out:
# 14:15:29 | INFO    | src.weather.ingestion | Forests: 4 features from doc.kml
# Forests: 4 polygons, CRS=EPSG:4326
#   id  Name description timestamp begin end altitudeMode  tessellate  extrude  visibility  drawOrder  icon         ha  \
# 0  0  None        None       NaT   NaT NaT         None          -1        0          -1        NaN  None    2302.37
# 1  0  None        None       NaT   NaT NaT         None          -1        0          -1        NaN  None    4822.38
# 2  0  None        None       NaT   NaT NaT         None          -1        0          -1        NaN  None  923302.00
# 3  0  None        None       NaT   NaT NaT         None          -1        0          -1        NaN  None    1520.72
#
#                                             geometry
# 0  MULTIPOLYGON Z (((46.77893 40.09749 0, 46.7788...
# 1  MULTIPOLYGON Z (((46.42709 40.15505 0, 46.4271...
# 2  MULTIPOLYGON Z (((48.64034 38.48963 0, 48.6402...
# 3  MULTIPOLYGON Z (((45.82352 39.01123 0, 45.8234...

# %%
try:
    landcover = ingestion.sample_landcover_at_cities()
    display(landcover)
except RuntimeError as exc:
    print(f"[skipped] {exc}")
    landcover = None
# Out:
# 14:15:50 | INFO    | src.weather.ingestion | Landcover: 16 cities sampled, classes = [0, 10, 20, 50]
#            City  Landcover_Class
# 0          Baku               50
# 1         Ganja               50
# 2      Lankaran               50
# 3          Guba               10
# 4      Zaqatala                0
# 5    Nakhchivan               50
# 6         Sheki               50
# 7       Shirvan               20
# 8   Mingachevir               10
# 9      Khachmaz               10
# 10      Goychay               50
# 11      Shamkir               50
# 12    Sabirabad               50
# 13      Imishli               50
# 14     Shamakhi               50
# 15    Jalilabad               50

# %% [markdown]
# ## 5. Run the full pipeline & persist interim outputs
#
# The orchestrator calls every loader, catches per-source failures and writes
# clean copies to `data/interim/`. Use `fmt='parquet'` in production (much
# smaller, typed); CSV is the portable default.

# %%
outputs = ingestion.run_ingestion_pipeline(use_api=False, fmt="csv", include_geo=True)

summary_rows = []
for name, df in outputs.items():
    summary_rows.append({"dataset": name, "rows": len(df), "cols": df.shape[1] if hasattr(df, 'shape') else None})
pd.DataFrame(summary_rows)
# Out:
# 14:15:51 | INFO    | src.weather.ingestion | ========================================================================
# 14:15:51 | INFO    | src.weather.ingestion | PHASE 1 - Data Ingestion pipeline starting
# 14:15:51 | INFO    | src.weather.ingestion | ========================================================================
# 14:15:51 | INFO    | src.weather.ingestion | Reading hourly weather  <- C:\Users\pc\Downloads\ARIAN\data\raw\openmeteo\hourly_weather.csv
# 14:15:54 | INFO    | src.weather.ingestion | Reading daily weather   <- C:\Users\pc\Downloads\ARIAN\data\raw\openmeteo\daily_weather.csv
# 14:15:54 | INFO    | src.weather.ingestion | Hourly: 276,000 rows, 5 cities, 2020-01-01 00:00:00+00:00 -> 2026-04-18 23:00:00+00:00
# 14:15:54 | INFO    | src.weather.ingestion | Daily:  11,500 rows, 5 cities, 2020-01-01 00:00:00+00:00 -> 2026-04-18 00:00:00+00:00
# 14:16:02 | INFO    | src.weather.ingestion | Saved 276,000 rows -> C:\Users\pc\Downloads\ARIAN\data\interim\weather_hourly_raw.csv (42.00 MB)
# 14:16:03 | INFO    | src.weather.ingestion | Saved 11,500 rows -> C:\Users\pc\Downloads\ARIAN\data\interim\weather_daily_raw.csv (0.42 MB)
# 14:16:03 | INFO    | src.weather.ingestion | Saved 16 rows -> C:\Users\pc\Downloads\ARIAN\data\interim\cities_reference.csv (0.00 MB)
# 14:16:03 | INFO    | src.weather.ingestion | Population: 112 rows across years 2020-2026, 16 cities
# 14:16:03 | INFO    | src.weather.ingestion | Saved 112 rows -> C:\Users\pc\Downloads\ARIAN\data\interim\population.csv (0.01 MB)
# 14:16:03 | INFO    | src.weather.ingestion | Roads: 16 cities, total 11537 km
# 14:16:03 | INFO    | src.weather.ingestion | Saved 16 rows -> C:\Users\pc\Downloads\ARIAN\data\interim\roads.csv (0.00 MB)
# 14:16:03 | INFO    | src.weather.ingestion | NDVI: 2304 rows, 16 cities, 2020-01-01 00:00:00+00:00 -> 2026-03-22 00:00:00+00:00
# 14:16:03 | INFO    | src.weather.ingestion | Saved 2,304 rows -> C:\Users\pc\Downloads\ARIAN\data\interim\ndvi.csv (0.09 MB)
# 14:16:03 | INFO    | src.weather.ingestion | FIRMS: 21218 hotspots, 2020-01-01 00:00:00 -> 2024-12-31 00:00:00
# 14:16:03 | INFO    | src.weather.ingestion | Saved 21,218 rows -> C:\Users\pc\Downloads\ARIAN\data\interim\firms.csv (2.12 MB)
# 14:16:04 | INFO    | src.weather.ingestion | Lightning: 366619 grid-month obs over 6 years
# 14:16:05 | INFO    | src.weather.ingestion | Saved 366,619 rows -> C:\Users\pc\Downloads\ARIAN\data\interim\lightning.csv (8.49 MB)
# 14:16:10 | INFO    | src.weather.ingestion | Forests: 4 features from doc.kml
# 14:16:37 | INFO    | pyogrio._io | Created 4 records
# 14:16:37 | INFO    | src.weather.ingestion | Saved 4 forest polygons -> C:\Users\pc\Downloads\ARIAN\data\interim\forest_boundaries.geojson
# 14:16:45 | INFO    | src.weather.ingestion | Landcover: 16 cities sampled, classes = [0, 10, 20, 50]
# 14:16:45 | INFO    | src.weather.ingestion | Saved 16 rows -> C:\Users\pc\Downloads\ARIAN\data\interim\landcover_at_cities.csv (0.00 MB)
# 14:16:45 | INFO    | src.weather.ingestion | ========================================================================
# 14:16:45 | INFO    | src.weather.ingestion | Ingestion complete - 10 datasets prepared in C:\Users\pc\Downloads\ARIAN\data\interim
# 14:16:45 | INFO    | src.weather.ingestion | ========================================================================
#           dataset    rows  cols
# 0  weather_hourly  276000    26
# 1   weather_daily   11500     3
# 2          cities      16     3
# 3      population     112     5
# 4           roads      16     2
# 5            ndvi    2304     3
# 6           firms   21218    16
# 7       lightning  366619     5
# 8         forests       4    14
# 9       landcover      16     2

# %%
# Inventory of interim/ — everything downstream Phase 2 will consume
from pathlib import Path
interim = sorted(INTERIM_DIR.glob("*"))
pd.DataFrame({
    "file": [p.name for p in interim],
    "size_MB": [round(p.stat().st_size / 1024 / 1024, 3) for p in interim],
})
# Out:
#                          file  size_MB
# 0        cities_reference.csv    0.000
# 1                   firms.csv    2.125
# 2   forest_boundaries.geojson  124.337
# 3     landcover_at_cities.csv    0.000
# 4               lightning.csv    8.487
# 5   multi_horizon_summary.csv    0.004
# 6                    ndvi.csv    0.093
# 7              population.csv    0.005
# 8                   roads.csv    0.000
# 9                 summary.csv    0.002
# 10    weather_daily_clean.csv    3.496
# 11      weather_daily_raw.csv    0.424
# 12       weather_forecast.csv    0.046
# 13   weather_hourly_clean.csv   48.578
# 14     weather_hourly_raw.csv   42.001

# %% [markdown]
# ## 6. Quick visual QC
#
# A first sanity check that the hourly weather pulled from Open-Meteo looks
# physically reasonable — temperature should show a clean annual cycle, and
# the cities should all share the same envelope with local shifts.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(13, 4))
for city, g in weather_hourly.groupby("City"):
    # Daily mean for legibility across ~55k hours
    daily = g.set_index("date")["temperature_2m"].resample("D").mean()
    ax.plot(daily.index, daily.values, label=city, lw=0.8, alpha=0.75)

ax.set_title("Daily mean 2 m temperature, 2020–2026")
ax.set_ylabel("°C"); ax.set_xlabel("date")
ax.legend(ncol=5, fontsize=8, loc="lower center")
ax.grid(alpha=0.3)
plt.tight_layout(); plt.show()

# %%
# Missingness map per variable and per city — shows if any source station dropped a column
miss = (
    weather_hourly
    .drop(columns=["date"])
    .groupby("City")
    .apply(lambda g: g.isna().mean().round(3), include_groups=False)
)
miss.style.background_gradient(cmap="Reds", vmin=0, vmax=0.2) if hasattr(miss, "style") else miss
# Out:
# <style type="text/css">
# #T_e587b_row0_col0, #T_e587b_row0_col1, #T_e587b_row0_col2, #T_e587b_row0_col3, #T_e587b_row0_col4, #T_e587b_row0_col5, #T_e587b_row0_col6, #T_e587b_row0_col7, #T_e587b_row0_col8, #T_e587b_row0_col9, #T_e587b_row0_col11, #T_e587b_row0_col12, #T_e587b_row0_col16, #T_e587b_row0_col17, #T_e587b_row0_col18, #T_e587b_row0_col19, #T_e587b_row0_col20, #T_e587b_row0_col21, #T_e587b_row0_col22, #T_e587b_row0_col23, #T_e587b_row1_col0, #T_e587b_row1_col1, #T_e587b_row1_col2, #T_e587b_row1_col3, #T_e587b_row1_col4, #T_e587b_row1_col5, #T_e587b_row1_col6, #T_e587b_row1_col7, #T_e587b_row1_col8, #T_e587b_row1_col9, #T_e587b_row1_col11, #T_e587b_row1_col12, #T_e587b_row1_col16, #T_e587b_row1_col17, #T_e587b_row1_col18, #T_e587b_row1_col19, #T_e587b_row1_col20, #T_e587b_row1_col21, #T_e587b_row1_col22, #T_e587b_row1_col23, #T_e587b_row2_col0, #T_e587b_row2_col1, #T_e587b_row2_col2, #T_e587b_row2_col3, #T_e587b_row2_col4, #T_e587b_row2_col5, #T_e587b_row2_col6, #T_e587b_row2_col7, #T_e587b_row2_col8, #T_e587b_row2_col9, #T_e587b_row2_col11, #T_e587b_row2_col12, #T_e587b_row2_col16, #T_e587b_row2_col17, #T_e587b_row2_col18, #T_e587b_row2_col19, #T_e587b_row2_col20, #T_e587b_row2_col21, #T_e587b_row2_col22, #T_e587b_row2_col23, #T_e587b_row3_col0, #T_e587b_row3_col1, #T_e587b_row3_col2, #T_e587b_row3_col3, #T_e587b_row3_col4, #T_e587b_row3_col5, #T_e587b_row3_col6, #T_e587b_row3_col7, #T_e587b_row3_col8, #T_e587b_row3_col9, #T_e587b_row3_col11, #T_e587b_row3_col12, #T_e587b_row3_col16, #T_e587b_row3_col17, #T_e587b_row3_col18, #T_e587b_row3_col19, #T_e587b_row3_col20, #T_e587b_row3_col21, #T_e587b_row3_col22, #T_e587b_row3_col23, #T_e587b_row4_col0, #T_e587b_row4_col1, #T_e587b_row4_col2, #T_e587b_row4_col3, #T_e587b_row4_col4, #T_e587b_row4_col5, #T_e587b_row4_col6, #T_e587b_row4_col7, #T_e587b_row4_col8, #T_e587b_row4_col9, #T_e587b_row4_col11, #T_e587b_row4_col12, #T_e587b_row4_col16, #T_e587b_row4_col17, #T_e587b_row4_col18, #T_e587b_row4_col19, #T_e587b_row4_col20, #T_e587b_row4_col21, #T_e587b_row4_col22, #T_e587b_row4_col23 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_e587b_row0_col10, #T_e587b_row0_col13, #T_e587b_row0_col14, #T_e587b_row0_col15, #T_e587b_row1_col10, #T_e587b_row1_col13, #T_e587b_row1_col14, #T_e587b_row1_col15, #T_e587b_row2_col10, #T_e587b_row2_col13, #T_e587b_row2_col14, #T_e587b_row2_col15, #T_e587b_row3_col10, #T_e587b_row3_col13, #T_e587b_row3_col14, #T_e587b_row3_col15, #T_e587b_row4_col10, #T_e587b_row4_col13, #T_e587b_row4_col14, #T_e587b_row4_col15 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e587b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e587b_level0_col0" class="col_heading level0 col0" >temperature_2m</th>
#       <th id="T_e587b_level0_col1" class="col_heading level0 col1" >relative_humidity_2m</th>
#       <th id="T_e587b_level0_col2" class="col_heading level0 col2" >dew_point_2m</th>
#       <th id="T_e587b_level0_col3" class="col_heading level0 col3" >precipitation</th>
#       <th id="T_e587b_level0_col4" class="col_heading level0 col4" >rain</th>
#       <th id="T_e587b_level0_col5" class="col_heading level0 col5" >cloud_cover</th>
#       <th id="T_e587b_level0_col6" class="col_heading level0 col6" >cloud_cover_low</th>
#       <th id="T_e587b_level0_col7" class="col_heading level0 col7" >cloud_cover_mid</th>
#       <th id="T_e587b_level0_col8" class="col_heading level0 col8" >cloud_cover_high</th>
#       <th id="T_e587b_level0_col9" class="col_heading level0 col9" >vapour_pressure_deficit</th>
#       <th id="T_e587b_level0_col10" class="col_heading level0 col10" >evapotranspiration</th>
#       <th id="T_e587b_level0_col11" class="col_heading level0 col11" >wind_speed_10m</th>
#       <th id="T_e587b_level0_col12" class="col_heading level0 col12" >wind_direction_10m</th>
#       <th id="T_e587b_level0_col13" class="col_heading level0 col13" >wind_speed_80m</th>
#       <th id="T_e587b_level0_col14" class="col_heading level0 col14" >wind_direction_80m</th>
#       <th id="T_e587b_level0_col15" class="col_heading level0 col15" >temperature_80m</th>
#       <th id="T_e587b_level0_col16" class="col_heading level0 col16" >wind_gusts_10m</th>
#       <th id="T_e587b_level0_col17" class="col_heading level0 col17" >soil_temperature_0_to_7cm</th>
#       <th id="T_e587b_level0_col18" class="col_heading level0 col18" >soil_temperature_7_to_28cm</th>
#       <th id="T_e587b_level0_col19" class="col_heading level0 col19" >soil_temperature_28_to_100cm</th>
#       <th id="T_e587b_level0_col20" class="col_heading level0 col20" >is_day</th>
#       <th id="T_e587b_level0_col21" class="col_heading level0 col21" >sunshine_duration</th>
#       <th id="T_e587b_level0_col22" class="col_heading level0 col22" >shortwave_radiation</th>
#       <th id="T_e587b_level0_col23" class="col_heading level0 col23" >direct_radiation</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >City</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e587b_level0_row0" class="row_heading level0 row0" >Baku</th>
#       <td id="T_e587b_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_e587b_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_e587b_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_e587b_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_e587b_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_e587b_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_e587b_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_e587b_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_e587b_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_e587b_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_e587b_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_e587b_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_e587b_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_e587b_row0_col13" class="data row0 col13" >1.000000</td>
#       <td id="T_e587b_row0_col14" class="data row0 col14" >1.000000</td>
#       <td id="T_e587b_row0_col15" class="data row0 col15" >1.000000</td>
#       <td id="T_e587b_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_e587b_row0_col17" class="data row0 col17" >0.000000</td>
#       <td id="T_e587b_row0_col18" class="data row0 col18" >0.000000</td>
#       <td id="T_e587b_row0_col19" class="data row0 col19" >0.000000</td>
#       <td id="T_e587b_row0_col20" class="data row0 col20" >0.000000</td>
#       <td id="T_e587b_row0_col21" class="data row0 col21" >0.000000</td>
#       <td id="T_e587b_row0_col22" class="data row0 col22" >0.000000</td>
#       <td id="T_e587b_row0_col23" class="data row0 col23" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e587b_level0_row1" class="row_heading level0 row1" >Ganja</th>
#       <td id="T_e587b_row1_col0" class="data row1 col0" >0.000000</td>
#       <td i

# %% [markdown]
# ## 7. Hand-off to Phase 2
#
# Everything Phase 2 (weather cleaning + modelling) needs is now in
# `data/interim/`:
#
# 1. **`weather_hourly_raw.csv`** — the core forecasting dataset
# 2. **`weather_daily_raw.csv`** — daily rain-sum reference
# 3. **`cities_reference.csv`** — 16 study locations
# 4. **Auxiliary frames** — population, roads, ndvi, firms, lightning
#    (the wildfire system in Phase 4 will consume these)
#
# Forecast targets (per `src.utils.config.FORECAST_TARGETS`):

# %%
print("Forecast targets:", FORECAST_TARGETS)
print("\nTargets available in weather_hourly:",
      [t for t in FORECAST_TARGETS if t in weather_hourly.columns])
missing = [t for t in FORECAST_TARGETS if t not in weather_hourly.columns]
print("Missing:", missing or "(none)")
# Out:
# Forecast targets: ['temperature_2m', 'wind_speed_10m', 'wind_direction_10m', 'rain', 'precipitation']
#
# Targets available in weather_hourly: ['temperature_2m', 'wind_speed_10m', 'wind_direction_10m', 'rain', 'precipitation']
# Missing: (none)

# %% [markdown]
# ---
# **Phase 1 ✅ complete.** Move to `02_weather_cleaning.ipynb`.
